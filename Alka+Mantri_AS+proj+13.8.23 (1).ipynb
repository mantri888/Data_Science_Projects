# %%
# import the important packages
import pandas as pd  # library used for data manipulation and analysis

import numpy as np  # library used for working with arrays

import matplotlib.pyplot as plt  # library for visualization

import seaborn as sns  # library for visualization

# %matplotlib inline

import scipy.stats as stats  # this library contains a large number of probability distributions as well as a growing library of statistical functions
from scipy.stats import norm
from scipy.stats import   ttest_1samp,ttest_ind,levene, shapiro
from statsmodels.formula.api import ols      # For n-way ANOVA
from statsmodels.stats.anova import _get_covariance,anova_lm # For n-way ANOVA

# %% [markdown]
# # Q3.The breaking strength of gunny bags used for packaging cement is normally distributed with a mean of 5 kg per sq. centimeter and a standard deviation of 1.5 kg per sq. centimeter. The quality team of the cement company wants to know the following about the packaging material to better understand wastage or pilferage within the supply chain; Answer the questions below based on the given information; (Provide an appropriate visual representation of your answers, without which marks will be deducted)

# %%
mu=5
sigma=1.5

# %%
x = np.linspace((mu - 4*sigma), (mu + 4*sigma), 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.title('Normal Distribution')
plt.xlabel('Breaking Strength')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# # What proportion of the gunny bags have a breaking strength less than 3.17 kg per sq cm?

# %%
#Lets plot the Graph of breaking strenhth

plt.plot(x,stats.norm.pdf(x,mu,sigma))
plt.axvline(x=3.17,c='red')
x1=np.linspace(mu-4*sigma,3.17,50)
plt.fill_between(x1,norm.pdf(x1,mu,sigma),color='pink')
plt.title('Normal Distribution')
plt.xlabel('Breaking Strength')
plt.ylabel('Density')
plt.show()

# %%
x=3.17
z=(x-mu)/sigma
p=stats.norm.cdf(z)
print('Proportion of the gunny bags have a breaking strength less than 3.17 kg per sq cm is %1.4f' %p)
# Out:
# Proportion of the gunny bags have a breaking strength less than 3.17 kg per sq cm is 0.1112

# %% [markdown]
# # Insight:
# So, about 11.12% of the gunny bags have a breaking strength less than 3.17 kg per sq cm.

# %% [markdown]
# # 3.2 What proportion of the gunny bags have a breaking strength at least 3.6 kg per sq cm.?

# %%
plt.plot(x,stats.norm.pdf(x,mu,sigma))
plt.axvline(x=3.6,c='red')
x1 = np.linspace(3.6,mu+4*sigma, 50)
plt.fill_between(x1,norm.pdf(x1,mu,sigma),color='pink')
plt.title('Normal Distribution')
plt.xlabel('Breaking Strength')
plt.ylabel('Density')
plt.show()

# %%
Prob=1-stats.norm.cdf(3.6,loc=5,scale=1.5)
print('Proportion of the gunny bags have a breaking strength at least 3.6 kg per sq cm is %1.4f' %Prob)
# Out:
# Proportion of the gunny bags have a breaking strength at least 3.6 kg per sq cm is 0.8247

# %% [markdown]
# # Insight:
# Proportion of the gunny bags have a breaking strength at least 3.6 kg per sq cm is 0.8247 or 82.47%

# %% [markdown]
# # 3.3 What proportion of the gunny bags have a breaking strength between 5 and 5.5 kg per sq cm.?

# %%
plt.plot(x,stats.norm.pdf(x,mu,sigma))
plt.axvline(x=5,c='red')
plt.axvline(x=5.5,c='red')
x1 = np.linspace(5,5.5,50)
plt.fill_between(x1,norm.pdf(x1,mu,sigma),color='pink')
plt.title('Normal Distribution')
plt.xlabel('Breaking Strength')
plt.ylabel('Density')
plt.show()

# %%
Prob1=stats.norm.cdf(5.5,loc=5,scale=1.5)-stats.norm.cdf(5,loc=5,scale=1.5)
print('Proportion of the gunny bags have a breaking strength between 5 and 5.5 kg per sq cm is %1.4f' %Prob1)
# Out:
# Proportion of the gunny bags have a breaking strength between 5 and 5.5 kg per sq cm is 0.1306

# %% [markdown]
# # Insight:
# so ,the gunny bags have a breaking strength between 5 and 5.5 kg per sq cm 0.1306 or 13.06%

# %% [markdown]
# # 3.4 What proportion of the gunny bags have a breaking strength NOT between 3 and 7.5 kg per sq cm.?

# %%
plt.plot(x,stats.norm.pdf(x,mu,sigma))
plt.axvline(x=3,c='red')
plt.axvline(x=7.5,c='red')
x1 = np.linspace(mu-4*sigma,3,50)
plt.fill_between(x1,norm.pdf(x1,mu,sigma),color='pink')
x2=np.linspace(7.5,mu+4*sigma,50)
plt.fill_between(x2,norm.pdf(x2,mu,sigma),color='pink')
plt.title('Normal Distribution')
plt.xlabel('Breaking Strength')
plt.ylabel('Density')
plt.show()

# %%
1-stats.norm.cdf(7.5,loc=5,scale=1.5)+stats.norm.cdf(3,loc=5,scale=1.5)
# Out:
# 0.13900157199868257

# %% [markdown]
# # Insight:
#  Proportion of The gunny bags have a breaking strength NOT between 3 and 7.5 kg per sq cm is 0.13900157199868257 or 14%

# %% [markdown]
# # Q4 Grades of the final examination in a training course are found to be normally distributed, with a mean of 77 and a standard deviation of 8.5. Based on the given information answer the questions below.

# %% [markdown]
# # 4.1 What is the probability that a randomly chosen student gets a grade below 85 on this exam?

# %%
mu=77
sigma=8.5

# %%
x = np.linspace((mu - 4*sigma), (mu + 4*sigma), 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.title('Normal Distribution of Exam Grades')
plt.xlabel('Grades')
plt.ylabel('Students prob')
plt.show()

# %%
Prob=stats.norm.cdf(85,loc=77,scale=8.5)
print('The probability that a randomly chosen student gets a grade below 85 on this exam is %1.4f' %Prob)
# Out:
# The probability that a randomly chosen student gets a grade below 85 on this exam is 0.8267

# %%
plt.plot(x,stats.norm.pdf(x,mu,sigma))
plt.axvline(x=85,c='red')
x1=np.linspace(mu-4*sigma,85,50)
plt.fill_between(x1,norm.pdf(x1,mu,sigma),color='pink')
plt.title('Normal Distribution of Exam Grades')
plt.xlabel('Grades')
plt.ylabel('Students prob')
plt.show()

# %% [markdown]
# # Insight:
# The probability that a randomly chosen student gets a grade below 85 on this exam is 0.8267 or 82.67%

# %% [markdown]
# # 4.2 What is the probability that a randomly selected student scores between 65 and 87?

# %%
Prob1=stats.norm.cdf(87,loc=77,scale=8.5)-stats.norm.cdf(65,loc=77,scale=8.5)
print('The probability that a randomly chosen student scores between 65 and 87 is  %1.4f' %Prob1)
# Out:
# The probability that a randomly chosen student scores between 65 and 87 is  0.8013

# %%
plt.plot(x,stats.norm.pdf(x,mu,sigma))
plt.axvline(x=65,c='red')
plt.axvline(x=87,c='red')
x1 = np.linspace(65,87,50)
plt.fill_between(x1,norm.pdf(x1,mu,sigma),color='pink')
plt.title('Normal Distribution of Exam Grades')
plt.xlabel('Grades')
plt.ylabel('Students prob')
plt.show()

# %% [markdown]
# # Insight:
# The probability that a randomly chosen student scores between 65 and 87 is 0.8013 or 80.13%

# %% [markdown]
# # 4.3 What should be the passing cut-off so that 75% of the students clear the exam?

# %%
# here we use the ppf function
stats.norm.ppf(0.75,loc=77,scale=8.5)
print('The passing cut-off so that 75% of the students clear the exam is' ,Prob1)
# Out:
# The passing cut-off so that 75% of the students clear the exam is 0.8012869336779058

# %%
plt.plot(x,stats.norm.pdf(x,mu,sigma))
plt.axvline(x=82,c='red')
x1=np.linspace(mu-4*sigma,85,50)
plt.fill_between(x1,norm.pdf(x1,mu,sigma),color='pink')
plt.title('Normal Distribution of Exam Grades')
plt.xlabel('Grades')
plt.ylabel('Students prob')
plt.show()

# %% [markdown]
# # Insight:
# The passing cut-off so that 75% of the students clear the exam is 82.86806082670591 or 82.86%

# %% [markdown]
# # Q5 Zingaro stone printing is a company that specializes in printing images or patterns on polished or unpolished stones. However, for the optimum level of printing of the image the stone surface has to have a Brinell's hardness index of at least 150. Recently, Zingaro has received a batch of polished and unpolished stones from its clients. Use the data provided to answer the following (assuming a 5% significance level);

# %% [markdown]
# # 5.1 Earlier experience of Zingaro with this particular client is favorable as the stone surface was found to be of adequate hardness. However, Zingaro has reason to believe now that the unpolished stones may not be suitable for printing. Do you think Zingaro is justified in thinking so?

# %% [markdown]
# # Loading dataset

# %%
df=pd.read_csv('Zingaro_Company.csv')

# %% [markdown]
# # Checking top 5 rows

# %%
df.head()
# Out:
#    Unpolished   Treated and Polished
# 0   164.481713            133.209393
# 1   154.307045            138.482771
# 2   129.861048            159.665201
# 3   159.096184            145.663528
# 4   135.256748            136.789227

# %% [markdown]
# # Checking shape of data

# %%
df.shape
# Out:
# (75, 2)

# %% [markdown]
# # Checking the  information of the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unpolished            75 non-null     float64
#  1   Treated and Polished  75 non-null     float64
# dtypes: float64(2)
# memory usage: 1.3 KB

# %% [markdown]
# # Checking the summery of dataframe

# %%
df.describe()
# Out:
#        Unpolished   Treated and Polished
# count    75.000000             75.000000
# mean    134.110527            147.788117
# std      33.041804             15.587355
# min      48.406838            107.524167
# 25%     115.329753            138.268300
# 50%     135.597121            145.721322
# 75%     158.215098            157.373318
# max     200.161313            192.272856

# %%
df.columns
# Out:
# Index(['Unpolished ', 'Treated and Polished'], dtype='object')

# %% [markdown]
# # Define null and alternative hypothesis

# %% [markdown]
# Null Hypothesis (H0): The mean (μU) Brinell's hardness index of unpolished stones is greater than or equal to 150.
# H0:μU≥150
#
# Alternative Hypothesis (H1): The mean (μU) Brinell's hardness index of unpolished stones is less than 150.
# H1:μU<150

# %% [markdown]
# # Decide the significance level

# %% [markdown]
# Here we select α= 0.05

# %%
print("The sample size for this problem is",len(df))
# Out:
# The sample size for this problem is 75

# %% [markdown]
# # Identify the test statistic

# %% [markdown]
# We do not know the population standard deviation and n = 75. So we use the t distribution and the tSTAT
# test statistic.

# %% [markdown]
# # Calculate the p - value and test statistic

# %%
#here we do One sample t test 
t_statistic, p_value = ttest_1samp(df['Unpolished '],150)
print('One sample t test \nt statistic: {0} p value: {1} '.format(t_statistic, p_value))
# Out:
# One sample t test
# t statistic: -4.164629601426757 p value: 8.342573994839304e-05

# %%
 #p_value < 0.05 => alternative hypothesis:

alpha_value = 0.05 # Level of significance
print('Level of significance: %.2f' %alpha_value)
if p_value < alpha_value: 
    print('We have evidence to reject the null hypothesis since p value < Level of significance')
else:
    print('We have no evidence to reject the null hypothesis since p value > Level of significance') 

print ("Our one-sample t-test p-value=", p_value)
# Out:
# Level of significance: 0.05
# We have evidence to reject the null hypothesis since p value < Level of significance
# Our one-sample t-test p-value= 8.342573994839304e-05

# %% [markdown]
# # Insights:
# In this example, p value is 8.34257399 4839304e-05 and it is less than 5% level of significance
#
# So the statistical decision is to reject the null hypothesis at 5% level of significance.
#
# So at 95% confidence level, there is no sufficient evidence to prove that The mean Brinell's hardness index of unpolished stones is greater than or equal to 150 so the unpolished stones are not  suitable for printing

# %% [markdown]
# # 5.2 Is the mean hardness of the polished and unpolished stones the same?

# %% [markdown]
# # Define null and alternative hypotheses

# %% [markdown]
# Null Hypothesis (H0)=The mean (μp) hardness of the polished stones is equal to The mean (μU) hardness of the unpolished stones. H0:μp=μU
# Alternative Hypothesis (H1)=The mean (μp) hardness of the polished stones is not equal to The mean (μU) hardness of the unpolished stones.
# H1:μp≠μU

# %% [markdown]
# Here we select α = 0.05 and the population standard deviation is not known.

# %%
X1_mean=df['Unpolished '].mean()
X2_mean=df['Treated and Polished'].mean()

# %%
print("The mean hardness of the polished stones is {} wheras the mean hardness of the unpolished stones is {}".format(X1_mean,X2_mean))
# Out:
# The mean hardness of the polished stones is 134.11052653373332 wheras the mean hardness of the unpolished stones is 147.78811718133335

# %%
#Here we perform two-sample t-test
t_statistic, p_value  = ttest_ind(df['Unpolished '],df['Treated and Polished'])
print('tstat',t_statistic)    
print('P Value',p_value)
# Out:
# tstat -3.2422320501414053
# P Value 0.0014655150194628353

# %%
# print ("two-sample t-test p-value=", p_value)

alpha_level = 0.05

if p_value < alpha_level:
    print('We have enough evidence to reject the null hypothesis in favour of alternative hypothesis')
    print('We conclude that The mean hardness of the polished stones is not equal to The mean hardness of the unpolished stones..')
else:
    print('We do not have enough evidence to reject the null hypothesis in favour of alternative hypothesis')
    print('We conclude that The mean hardness of the polished stones is  equal to The mean hardness of the unpolished stones')
# Out:
# We have enough evidence to reject the null hypothesis in favour of alternative hypothesis
# We conclude that The mean hardness of the polished stones is not equal to The mean hardness of the unpolished stones..

# %% [markdown]
# # Insights:
# From above result we can say that P value is less than the significance level so we have enough evidence to reject the null hypothesis in favour of alternative hypothesis.Hence We conclude that The mean hardness of the polished stones is not equal to The mean hardness of the unpolished stones

# %% [markdown]
# # 6.Aquarius health club, one of the largest and most popular cross-fit gyms in the country has been advertising a rigorous program for body conditioning. The program is considered successful if the candidate is able to do more than 5 push-ups, as compared to when he/she enrolled in the program. Using the sample data provided can you conclude whether the program is successful? (Consider the level of Significance as 5%)

# %% [markdown]
# # Importing CSV

# %%
Aquarius_gym= pd.read_csv('Aquarius_gym.csv')

# %% [markdown]
# # Checking the top 5 rows

# %%
Aquarius_gym.head()
# Out:
#    Sr no.  Before  After
# 0       1      39     44
# 1       2      25     25
# 2       3      39     39
# 3       4       6     13
# 4       5      40     44

# %% [markdown]
# # Checking Shape of data

# %%
Aquarius_gym.shape
# Out:
# (100, 3)

# %% [markdown]
# # Checking Information of data

# %%
Aquarius_gym.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sr no.  100 non-null    int64
#  1   Before  100 non-null    int64
#  2   After   100 non-null    int64
# dtypes: int64(3)
# memory usage: 2.5 KB

# %% [markdown]
# # Checking summery of Data

# %%
Aquarius_gym.describe()
# Out:
#            Sr no.      Before       After
# count  100.000000  100.000000  100.000000
# mean    50.500000   26.940000   32.490000
# std     29.011492    8.806357    8.779562
# min      1.000000    3.000000   10.000000
# 25%     25.750000   21.750000   26.000000
# 50%     50.500000   28.000000   34.000000
# 75%     75.250000   32.250000   39.000000
# max    100.000000   47.000000   51.000000

# %% [markdown]
# # Check for missing values

# %%
Aquarius_gym.isnull().sum()
# Out:
# Sr no.    0
# Before    0
# After     0
# dtype: int64

# %% [markdown]
# There are no missing values in the dataset.

# %% [markdown]
# # Plot Histograms and boxplot

# %%
Aquarius_gym.iloc[:,1:3].hist(figsize=(10,5))
plt.show()

# %%
## Plotting using seaborn 
plt.figure (figsize= (12,5))
plt.subplot (1,2,1)
sns.histplot(Aquarius_gym['Before'], color ='Red', kde =True);
plt.subplot (1,2,2)
sns.histplot(Aquarius_gym ['After'], color ='Blue', kde=True);
plt.tight_layout ()

# %%
sns.boxplot(x=Aquarius_gym['Before'],color='lightgreen')
# Out:
# <Axes: xlabel='Before'>

# %%
sns.boxplot(x=Aquarius_gym['After'],color='lightgreen')
# Out:
# <Axes: xlabel='After'>

# %%
#lets do shapiro test to see data is normally distributed or not
shapiro(Aquarius_gym['Before'])
# Out:
# ShapiroResult(statistic=0.9895846247673035, pvalue=0.6310927867889404)

# %% [markdown]
# P value (0.63) is greater than 0.05 which means do not reject Null hypothesis which means Data is Normal

# %%
shapiro(Aquarius_gym['After'])
# Out:
# ShapiroResult(statistic=0.9847944974899292, pvalue=0.3069112300872803)

# %% [markdown]
# P value (0.30) is greater than 0.05 which means do not reject Null hypothesis which means Data is Normal

# %%
# For checking equality of variance between groups
# Null Hypothesis: Variances are equal
levene(Aquarius_gym['Before'],Aquarius_gym['After'])
# Out:
# LeveneResult(statistic=0.004303876270947673, pvalue=0.947759347228822)

# %% [markdown]
# # Insights
# P value (0.94) is greater than 0.05 which means do not reject Null hypothesis which means Variances are equal
#
# Mean and Median Values of each sample are not much different.
#
# The Before data looks more symmetrically distributed, whereas the New scheme data looks left skewed.

# %%
print("The sample size for this problem is",len(Aquarius_gym))
# Out:
# The sample size for this problem is 100

# %% [markdown]
# # Define null and alternative hypotheses

# %% [markdown]
# Let's assume that the null hypothesis (H0) states that the program is not successful, and the alternative hypothesis (Ha) states that the program is successful (i.e., the mean difference is greater than 5). Mathematically, we can express this as:
# H0: μd ≤ 5 (Null hypothesis: The mean difference is less than or equal to 5 push-ups.)
# Ha: μd > 5 (Alternative hypothesis: The mean difference is greater than 5 push-ups.)

# %% [markdown]
# Here we select α= 0.05 as given in the question.

# %% [markdown]
#  Identify the test statistic
# Sample sizes for both samples are same.
# We have two paired samples and we do not know the population standard deviation.
# So we use the t distribution and the tSTAT test statistic for two sample paired test.

# %% [markdown]
# # Calculate the p - value and test statistic

# %% [markdown]
# We use the scipy.stats.ttest_rel to calculate the T-test on TWO RELATED samples of scores. This is a two-sided test for the null hypothesis that 2 related or repeated samples have identical average (expected) values. Here we give the two sample observations as input. This function returns t statistic and two-tailed p value.

# %%
t, p_value  = stats.ttest_rel(Aquarius_gym['Before'],Aquarius_gym['After'])  #Performing a paired t-test
print('t',t)    
print('P Value',p_value)   #Python gives us a two tailed test. The pvalue here is for two-tailed test.
# Out:
# t -19.322619811082458
# P Value 2.2920419252511966e-35

# %%
#The following is the pvalue for a one-tailed test.

(p_value/2)
# Out:
# 1.1460209626255983e-35

# %%
print ("two-paired t-test p-value=", p_value/2)
alpha_value = 0.05 # Level of significance
print('Level of significance: %.2f' %alpha_value)
if p_value/2 < alpha_value: 
    print('We have evidence to reject the null hypothesis since p value < Level of significance')
else:
    print('We have no evidence to reject the null hypothesis since p value > Level of significance')
# Out:
# two-paired t-test p-value= 1.1460209626255983e-35
# Level of significance: 0.05
# We have evidence to reject the null hypothesis since p value < Level of significance

# %% [markdown]
# # Coclusion

# %% [markdown]
# In this scenario, the p value is 1.1460209626255983e-35 which is less than the 0.05. Hence we reject the null hypothesis in favour of alternative hypothesis that the program is not successful

# %% [markdown]
# # Power of test

# %%
(32-26)/np.mean([8,8])
# Out:
# 0.75

# %%
import statsmodels.stats.power as smp
smp.ttest_power(0.75, nobs=100, alpha=0.05)
# Out:
# 0.9999999769725726

# %% [markdown]
# # 7 Dental implant data: The hardness of metal implant in dental cavities depends on multiple factors, such as the method of implant, the temperature at which the metal is treated, the alloy used as well as on the dentists who may favour one method above another and may work better in his/her favourite method. The response is the variable of interest.

# %% [markdown]
# # 7.1Test whether there is any difference among the dentists on the implant hardness. State the null and alternative hypotheses. Note that both types of alloys cannot be considered together. You must state the null and alternative hypotheses separately for the two types of alloys.?

# %% [markdown]
# # 7.2 Before the hypotheses may be tested, state the required assumptions. Are the assumptions fulfilled? Comment separately on both alloy types.?

# %% [markdown]
# # 7.3 Irrespective of your conclusion in 7.2, we will continue with the testing procedure. What do you conclude regarding whether implant hardness depends on dentists? Clearly state your conclusion. If the null hypothesis is rejected, is it possible to identify which pairs of dentists differ?

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
from statsmodels.formula.api import ols      # For n-way ANOVA
from statsmodels.stats.anova import _get_covariance,anova_lm # For n-way ANOVA
from scipy.stats import f_oneway

# %% [markdown]
# # Importing Excel

# %%
Dental_data=pd.read_excel('Dental Hardness data.xlsx',sheet_name='Data')

# %% [markdown]
# # Checking the top 5 records

# %%
Dental_data.head()
# Out:
#    Dentist  Method  Alloy  Temp  Response
# 0        1       1      1  1500       813
# 1        1       1      1  1600       792
# 2        1       1      1  1700       792
# 3        1       1      2  1500       907
# 4        1       1      2  1600       792

# %% [markdown]
# # Checking the shape and information of the dataframe

# %%
Dental_data.shape
# Out:
# (90, 5)

# %%
Dental_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Dentist   90 non-null     int64
#  1   Method    90 non-null     int64
#  2   Alloy     90 non-null     int64
#  3   Temp      90 non-null     int64
#  4   Response  90 non-null     int64
# dtypes: int64(5)
# memory usage: 3.6 KB

# %%
Dental_data.isnull().sum()
# Out:
# Dentist     0
# Method      0
# Alloy       0
# Temp        0
# Response    0
# dtype: int64

# %% [markdown]
# # Checking the summary of the dataframe¶

# %%
Dental_data.describe()
# Out:
#          Dentist     Method      Alloy         Temp     Response
# count  90.000000  90.000000  90.000000    90.000000    90.000000
# mean    3.000000   2.000000   1.500000  1600.000000   741.777778
# std     1.422136   0.821071   0.502801    82.107083   145.767845
# min     1.000000   1.000000   1.000000  1500.000000   289.000000
# 25%     2.000000   1.000000   1.000000  1500.000000   698.000000
# 50%     3.000000   2.000000   1.500000  1600.000000   767.000000
# 75%     4.000000   3.000000   2.000000  1700.000000   824.000000
# max     5.000000   3.000000   2.000000  1700.000000  1115.000000

# %% [markdown]
# For ANNOVA testing dependent and independent variable should be in categorical form. here in given data variables are in the float format so we convert them into the categorical form

# %%
Dental_data['Dentist']=pd.Categorical(Dental_data['Dentist'])
Dental_data['Method']=pd.Categorical(Dental_data['Method'])
Dental_data['Alloy']=pd.Categorical(Dental_data['Alloy'])
Dental_data['Temp']=pd.Categorical(Dental_data['Temp'])

# %%
Dental_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Dentist   90 non-null     category
#  1   Method    90 non-null     category
#  2   Alloy     90 non-null     category
#  3   Temp      90 non-null     category
#  4   Response  90 non-null     int64
# dtypes: category(4), int64(1)
# memory usage: 1.8 KB

# %%
#Normality Assumption
#Null: The distribution is drawn from Normal Distribution
#Alternate: The distribution is not normal

# %%
sns.distplot(Dental_data['Response'])
# Out:
# C:\Users\mantr\AppData\Local\Temp\ipykernel_10060\1532601842.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Dental_data['Response'])
# <Axes: xlabel='Response', ylabel='Density'>

# %%
#Assumptions
stats.shapiro(Dental_data['Response'])
# Out:
# ShapiroResult(statistic=0.9065925478935242, pvalue=8.080212865024805e-06)

# %%
#pvalue< 0.05 Reject H0 - beco data is non-normal

# %% [markdown]
# # Formulate the Null and Alternate Hypothesis

# %% [markdown]
# Let's assume you have two types of alloys: Alloy 1 and Alloy 2. We will perform two separate ANOVA tests, one for each alloy type. The null and alternative hypotheses for each test are as follows:

# %% [markdown]
# # For Alloy 1

# %% [markdown]
# # Null Hypothesis (H0): There is no significant difference in implant hardness among the dentists for Alloy 1

# %% [markdown]
# # Alternative Hypothesis (Ha): There is a significant difference in implant hardness for at least one dentist for Alloy 1.

# %% [markdown]
# # for Alloy 2

# %% [markdown]
# # Null Hypothesis (H0): There is no significant difference in implant hardness among the dentists for Alloy 2.

# %% [markdown]
# # Alternative Hypothesis (Ha): There is a significant difference in implant hardness for at least one dentist for Alloy 2.

# %%
#Seperate data for Alloy1 and Alloy2
Alloy1_data=Dental_data[Dental_data['Alloy']==1]
Alloy2_data=Dental_data[Dental_data['Alloy']==2]

# %%
#The Shapiro-Wilk test tests the null hypothesis that the data was drawn from a normal distribution
#lets do shapiro test for variable Dentist & response to see the normality assumtion met or not for Alloy 1
dentist_1 = Alloy1_data[Alloy1_data['Dentist']==1]['Response']
dentist_2 = Alloy1_data[Alloy1_data['Dentist']==2]['Response']
dentist_3 = Alloy1_data[Alloy1_data['Dentist']==3]['Response']
dentist_4 = Alloy1_data[Alloy1_data['Dentist']==4]['Response']
dentist_5 = Alloy1_data[Alloy1_data['Dentist']==5]['Response']

# %%
from scipy import stats
#The Shapiro-Wilk test tests the null hypothesis that the data was drawn from a normal distribution.
#alpha = 0.05
#perform shapiro test for Alloy 1
print(stats.shapiro([dentist_1 ]))
print(stats.shapiro([dentist_2 ]))
print(stats.shapiro([dentist_3]))
print(stats.shapiro([dentist_4]))
print(stats.shapiro([dentist_5]))
# Out:
# ShapiroResult(statistic=0.9113541841506958, pvalue=0.3254688084125519)
# ShapiroResult(statistic=0.9642462134361267, pvalue=0.8415456414222717)
# ShapiroResult(statistic=0.8721169233322144, pvalue=0.12953516840934753)
# ShapiroResult(statistic=0.8368974328041077, pvalue=0.05333680287003517)
# ShapiroResult(statistic=0.8534296751022339, pvalue=0.08127813786268234)

# %% [markdown]
# # From  Shapiro result  for Alloy 1 we can see that all  p value are greater than 0.05(alpha) so here we can say that data is normally distributed means the normality assumption is met for Alloy 1

# %% [markdown]
# Let us now perform One Way ANOVA with the variable 'Dentist with respect to 'Response' for Alloy 1

# %%
#One-way Annova test for Alloy 1
formula = 'Response ~ C(Dentist)'#Dentist as a function of Response, target variable dependent on Independent variable 
model = ols(formula, Alloy1_data).fit()#building and fitting model
aov_table = anova_lm(model) #extract the anova table from model
(aov_table)
# Out:
#               df         sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  106683.688889  26670.922222  1.977112  0.116567
# Residual    40.0  539593.555556  13489.838889       NaN       NaN

# %% [markdown]
# To confirm that there is no difference in any pair of dentist we perform  TukeyHSD test for Alloy 1.

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd
tukey_results_Alloy1 = pairwise_tukeyhsd(endog=Alloy1_data['Response'], groups=Alloy1_data['Dentist'], alpha=0.05)
print(tukey_results_Alloy1)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#      1      2   11.3333 0.9996 -145.0423  167.709  False
#      1      3  -32.3333 0.9757  -188.709 124.0423  False
#      1      4  -68.7778 0.7189 -225.1535  87.5979  False
#      1      5 -122.2222 0.1889 -278.5979  34.1535  False
#      2      3  -43.6667 0.9298 -200.0423  112.709  False
#      2      4  -80.1111 0.5916 -236.4868  76.2646  False
#      2      5 -133.5556 0.1258 -289.9312  22.8201  False
#      3      4  -36.4444 0.9626 -192.8201 119.9312  False
#      3      5  -89.8889 0.4805 -246.2646  66.4868  False
#      4      5  -53.4444 0.8643 -209.8201 102.9312  False
# --------------------------------------------------------

# %%
#plotting TukeyHSD
tukey_results_Alloy1.plot_simultaneous(figsize=(7,4))

plt.vlines(x=741.77,ymin=-0.5,ymax=3.5, color="red") ;

# %% [markdown]
# # Now, we see that the corresponding p-value is greater than alpha (0.05). Thus, we fail to reject the Null Hypothesis(H0).so There is no significant difference in implant among the dentists for Alloy 1.

# %%
#shapiro test for Alloy 2
Dentist_1 = Alloy2_data[Alloy2_data['Dentist']==1]['Response']
Dentist_2 = Alloy2_data[Alloy2_data['Dentist']==2]['Response']
Dentist_3 = Alloy2_data[Alloy2_data['Dentist']==3]['Response']
Dentist_4 = Alloy2_data[Alloy2_data['Dentist']==4]['Response']
Dentist_5 = Alloy2_data[Alloy2_data['Dentist']==5]['Response']

# %%
#alpha = 0.05
print(stats.shapiro([Dentist_1]))
print(stats.shapiro([Dentist_2]))
print(stats.shapiro([Dentist_3]))
print(stats.shapiro([Dentist_4]))
print(stats.shapiro([Dentist_5]))
# Out:
# ShapiroResult(statistic=0.9039731621742249, pvalue=0.27593979239463806)
# ShapiroResult(statistic=0.9392004013061523, pvalue=0.5735077857971191)
# ShapiroResult(statistic=0.9340971112251282, pvalue=0.5213080644607544)
# ShapiroResult(statistic=0.7613219022750854, pvalue=0.007332688197493553)
# ShapiroResult(statistic=0.9131584167480469, pvalue=0.33861100673675537)

# %% [markdown]
# # From  Shapiro result  for Alloy 2 we can see that all  p value are greater than 0.05(alpha) so here we can say that data is normally distributed means the normality assumption is met for Alloy 2

# %% [markdown]
# Let us now perform One Way ANOVA with the variable 'Dentist with respect to 'Response' for Alloy2

# %%
#One-way Annova test for Alloy 2
formula = 'Response ~ C(Dentist)'#Dentist as a function of Response, target variable dependent on Independent variable 
model = ols(formula, Alloy2_data).fit()#building and fitting model
aov_table = anova_lm(model) #extract the anova table from model
(aov_table)
# Out:
#               df        sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  5.679791e+04  14199.477778  0.524835  0.718031
# Residual    40.0  1.082205e+06  27055.122222       NaN       NaN

# %% [markdown]
# # Here, we see that the corresponding p-value is greater than alpha (0.05). Thus, we fail to reject the Null Hypothesis(H0).so There is no significant difference in implant among the dentists for Alloy 2.

# %% [markdown]
# Lets perform TukeyHSD test

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd

tukey_results_Alloy2 = pairwise_tukeyhsd(endog=Alloy2_data['Response'], groups=Alloy2_data['Dentist'], alpha=0.05)
print(tukey_results_Alloy2)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#      1      2  -4.1111    1.0 -225.5687 217.3465  False
#      1      3 -36.5556 0.9895 -258.0131  184.902  False
#      1      4    -70.0 0.8941 -291.4576 151.4576  False
#      1      5 -90.1111 0.7724 -311.5687 131.3465  False
#      2      3 -32.4444 0.9933  -253.902 189.0131  False
#      2      4 -65.8889 0.9132 -287.3465 155.5687  False
#      2      5    -86.0 0.8008 -307.4576 135.4576  False
#      3      4 -33.4444 0.9925  -254.902 188.0131  False
#      3      5 -53.5556 0.9574 -275.0131  167.902  False
#      4      5 -20.1111  0.999 -241.5687 201.3465  False
# -------------------------------------------------------

# %%
#Plotting TukeyHSD
tukey_results_Alloy2.plot_simultaneous(figsize=(7,4))

plt.vlines(x=741.77,ymin=-0.5,ymax=3.5, color="red") ;

# %% [markdown]
# # Q7.4 Now test whether there is any difference among the methods on the hardness of dental implant, separately for the two types of alloys. What are your conclusions? If the null hypothesis is rejected, is it possible to identify which pairs of methods differ?

# %% [markdown]
# # Formulate the Null and Alternate Hypothesis

# %% [markdown]
# # For Alloy 1

# %% [markdown]
# # Null Hypothesis (H0):  There is no significant difference among the methods in terms of implant hardness for the Alloy1

# %% [markdown]
# # Alternative Hypothesis  (Ha):  There is a significant difference among the methods in terms of implant hardness for the Alloy1

# %% [markdown]
# # For Alloy 2

# %% [markdown]
# # Null Hypothesis (H0):  There is no significant difference among the methods in terms of implant hardness for the Alloy2.

# %% [markdown]
# # Alternative Hypothesis  (Ha):  There is a significant difference among the methods in terms of implant hardness for the Alloy2

# %%
#The Shapiro-Wilk test tests the null hypothesis that the data was drawn from a normal distribution
#lets do shapiro test for variable Method & response to see the normality assumtion met or not for Alloy 1
method_1 = Alloy1_data[Alloy1_data['Method']==1]['Response']
method_2 = Alloy1_data[Alloy1_data['Method']==2]['Response']
method_3 = Alloy1_data[Alloy1_data['Method']==3]['Response']

# %%
#alpha = 0.05
#perform shapiro test for Alloy 1
print(stats.shapiro([method_1]))
print(stats.shapiro([method_2]))
print(stats.shapiro([method_3]))
# Out:
# ShapiroResult(statistic=0.9183822870254517, pvalue=0.18198540806770325)
# ShapiroResult(statistic=0.9732585549354553, pvalue=0.9030335545539856)
# ShapiroResult(statistic=0.9114548563957214, pvalue=0.14254699647426605)

# %% [markdown]
# # From  Shapiro result  for Alloy 1 we can see that all  p value are greater than 0.05(alpha) so here we can say that data is normally distributed for variables Method & Response. It means the normality assumption is met for Alloy 1

# %% [markdown]
# Let us now perform One Way ANOVA with the variable 'Method with respect to 'Response' for Alloy 1

# %%
#One-way Annova test for Alloy 1
formula = 'Response ~ C(Method)'#Dentist as a function of Response, target variable dependent on Independent variable 
model = ols(formula, Alloy1_data).fit()#building and fitting model
aov_table = anova_lm(model)
(aov_table)
# Out:
#              df         sum_sq       mean_sq         F    PR(>F)
# C(Method)   2.0  148472.177778  74236.088889  6.263327  0.004163
# Residual   42.0  497805.066667  11852.501587       NaN       NaN

# %% [markdown]
# # Now, we see that the corresponding p-value is less than alpha (0.05). Thus, we  𝐫𝐞𝐣𝐞𝐜𝐭 the  𝐍𝐮𝐥𝐥 𝐇𝐲𝐩𝐨𝐭𝐡𝐞𝐬𝐢𝐬(H0) for Alloy1 so There is a significant difference among the methods in terms of implant hardness for the Alloy1

# %%
#To confirm that there is no difference in any pair of method we perform  TukeyHSD test for Alloy 1.
tukey_results_MAlloy1 = pairwise_tukeyhsd(endog=Alloy1_data['Response'], groups=Alloy1_data['Method'], alpha=0.05)
print(tukey_results_MAlloy1)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#      1      2   -6.1333  0.987  -102.714  90.4473  False
#      1      3    -124.8 0.0085 -221.3807 -28.2193   True
#      2      3 -118.6667 0.0128 -215.2473  -22.086   True
# --------------------------------------------------------

# %%
#Plotting TukeyHSD

tukey_results_MAlloy1.plot_simultaneous(figsize=(7,4))
plt.vlines(x=741.77,ymin=-0.5,ymax=3.5, color="red") ;

# %%
#The Shapiro-Wilk test tests the null hypothesis that the data was drawn from a normal distribution
#lets do shapiro test for variable Method & response to see the normality assumtion met or not for Alloy 2
Method_1 = Alloy2_data[Alloy2_data['Method']==1]['Response']
Method_2 = Alloy2_data[Alloy2_data['Method']==2]['Response']
Method_3 = Alloy2_data[Alloy2_data['Method']==3]['Response']

# %%
#alpha = 0.05
#perform shapiro test for Alloy 2
print(stats.shapiro([Method_1]))
print(stats.shapiro([Method_2]))
print(stats.shapiro([Method_3]))
# Out:
# ShapiroResult(statistic=0.963810384273529, pvalue=0.7582374811172485)
# ShapiroResult(statistic=0.755793035030365, pvalue=0.001051110913977027)
# ShapiroResult(statistic=0.9021322131156921, pvalue=0.1025901660323143)

# %% [markdown]
# # From  Shapiro result  for Alloy 2 we can see that all  p value are greater than 0.05(alpha) so here we can say that data is normally distributed for variables Method & Response. It means the normality assumption is met for Alloy2

# %%
#One-way Annova test for Alloy 2
formula = 'Response ~ C(Method)'#Dentist as a function of Response, target variable dependent on Independent variable 
model = ols(formula, Alloy2_data).fit()#building and fitting model
aov_table = anova_lm(model) #extract the anova table from model
(aov_table)
# Out:
#              df    sum_sq        mean_sq        F    PR(>F)
# C(Method)   2.0  499640.4  249820.200000  16.4108  0.000005
# Residual   42.0  639362.4   15222.914286      NaN       NaN

# %% [markdown]
# # Now, we see that the corresponding p-value is less than alpha (0.05). Thus, we  𝐫𝐞𝐣𝐞𝐜𝐭 the  𝐍𝐮𝐥𝐥 𝐇𝐲𝐩𝐨𝐭𝐡𝐞𝐬𝐢𝐬( 𝐻0).For Alloy 2.so There is a significant difference among the methods in terms of implant hardness for the Alloy2

# %%
tukey_results_MAlloy2 = pairwise_tukeyhsd(endog=Alloy2_data['Response'], groups=Alloy1_data['Method'], alpha=0.05)
print(tukey_results_MAlloy2)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower     upper   reject
# --------------------------------------------------------
#      1      2     27.0 0.8212  -82.4546  136.4546  False
#      1      3   -208.8 0.0001 -318.2546  -99.3454   True
#      2      3   -235.8    0.0 -345.2546 -126.3454   True
# --------------------------------------------------------

# %%
#Plotting TukeyHSD
tukey_results_MAlloy2.plot_simultaneous(figsize=(7,4))
plt.vlines(x=741.77,ymin=-0.5,ymax=3.5, color="red") ;

# %% [markdown]
# # 7.57.5 Now test whether there is any difference among the temperature levels on the hardness of dental implant, separately for the two types of alloys. What are your conclusions? If the null hypothesis is rejected, is it possible to identify which levels of temperatures differ?

# %% [markdown]
# # Formulate the Null and Alternate Hypothesis

# %% [markdown]
# # For Alloy 1

# %% [markdown]
# # Null Hypothesis (H0):  There is no significant difference among the temperature in terms of implant hardness for the Alloy1

# %% [markdown]
# # Alternative Hypothesis  (Ha):  There is a significant difference among the temperature in terms of implant hardness for the Alloy2

# %% [markdown]
# # For Alloy 2

# %% [markdown]
# # Null Hypothesis (H0):  There is no significant difference among the temperature in terms of implant hardness for the Alloy1

# %% [markdown]
# # Alternative Hypothesis  (Ha):  There is a significant difference among the temperature in terms of implant hardness for the Alloy2

# %% [markdown]
# Let us now perform One Way ANOVA with the variable 'Temprature with respect to 'Response' for Alloy 1

# %%
formula = 'Response ~ C(Temp)'#Dentist as a function of Response, target variable dependent on Independent variable 
model = ols(formula, Alloy1_data).fit()#building and fitting model
aov_table = anova_lm(model) #extract the anova table from model
(aov_table)
# Out:
#             df         sum_sq       mean_sq         F    PR(>F)
# C(Temp)    2.0   10154.444444   5077.222222  0.335224  0.717074
# Residual  42.0  636122.800000  15145.780952       NaN       NaN

# %% [markdown]
# # Here, we see that the corresponding p-value is greater than alpha (0.05). Thus, we fail to reject the Null Hypothesis(H0).so There is no significant difference in implant hardness among the Temperature for Alloy 1.

# %%
#perform Tukeys HSD test
tukey_results_TAlloy1 = pairwise_tukeyhsd(endog=Alloy1_data['Response'], groups=Alloy1_data['Temp'], alpha=0.05)
print(tukey_results_TAlloy1)
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower    upper  reject
# ------------------------------------------------------
#   1500   1600 -15.6667 0.9353 -124.8436 93.5103  False
#   1500   1700 -36.6667 0.6953 -145.8436 72.5103  False
#   1600   1700    -21.0 0.8869  -130.177  88.177  False
# ------------------------------------------------------

# %%
tukey_results_TAlloy1.plot_simultaneous(figsize=(7,4))
plt.vlines(x=741.77,ymin=-0.5,ymax=3.5, color="red") ;

# %%
formula = 'Response ~ C(Temp)'#Dentist as a function of Response, target variable dependent on Independent variable 
model = ols(formula, Alloy2_data).fit()#building and fitting model
aov_table = anova_lm(model) #extract the anova table from model
(aov_table)
# Out:
#             df        sum_sq       mean_sq         F    PR(>F)
# C(Temp)    2.0  9.374893e+04  46874.466667  1.883492  0.164678
# Residual  42.0  1.045254e+06  24886.996825       NaN       NaN

# %% [markdown]
# # Here, we see that the corresponding p-value is greater than alpha (0.05). Thus, we fail to reject the Null Hypothesis(H0).so There is no significant difference in implant hardness among the Temperature for Alloy 2.

# %%
tukey_results_TAlloy2 = pairwise_tukeyhsd(endog=Alloy2_data['Response'], groups=Alloy2_data['Temp'], alpha=0.05)
print(tukey_results_TAlloy2)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#   1500   1600  -26.3333 0.8915 -166.2828 113.6162  False
#   1500   1700 -107.2667 0.1624 -247.2162  32.6828  False
#   1600   1700  -80.9333 0.3475 -220.8828  59.0162  False
# --------------------------------------------------------

# %%
tukey_results_TAlloy2.plot_simultaneous(figsize=(7,4))
plt.vlines(x=741.77,ymin=-0.5,ymax=3.5, color="red") ;

# %% [markdown]
# # 7.6 Consider the interaction effect of dentist and method and comment on the interaction plot, separately for the two types of alloys?

# %% [markdown]
# # The Hypothesis for the Two Way ANOVA without including Interaction effect For Alloy1 are:

# %% [markdown]
# # Null Hypothesis: Avg implant hardness of the patient  is equal accross all Dentist categories and method used for treatment for Alloy 1

# %% [markdown]
# # Alternate Hopthesis:Avg implant hardness of the patient  is  not equal accross all Dentist categories and method used for treatment for Alloy 1

# %%
formula = 'Response ~ C(Dentist) + C(Method)'
model = ols(formula, Alloy1_data).fit()
aov_table = anova_lm(model)
(aov_table)
# Out:
#               df         sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  106683.688889  26670.922222  2.591255  0.051875
# C(Method)    2.0  148472.177778  74236.088889  7.212522  0.002211
# Residual    38.0  391121.377778  10292.667836       NaN       NaN

# %% [markdown]
# #The p-value in the one of the treatments is equal to 𝛼(0.05)

# %% [markdown]
# Let us check whether there is any interaction effect between the treatments.
#
# Statistically, At 5% level of significance,The implant hardness not dependant on dentist but it gets affected by method that used for impanting. for Alloy 1

# %%
#lets check interaction effect between method & Dentist used for implanting for Alloy 1
sns.pointplot(x='Dentist', y='Response', data=Alloy1_data, hue='Method',ci=None);
# Out:
# C:\Users\mantr\AppData\Local\Temp\ipykernel_10060\550198069.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(x='Dentist', y='Response', data=Alloy1_data, hue='Method',ci=None);

# %% [markdown]
# Still, we can see that there is some sort of interaction between the two treatments. So, we will introduce a new term while performing the Two Way ANOVA.

# %% [raw]
# # There is Interaction betweent method of treatment and Dentist for Alloy 1

# %% [markdown]
# # The Hypothesis for the Two Way ANOVA without including Interaction effect For Alloy 2 are:

# %% [markdown]
# # Null Hypothesis: Avg implant hardness of the patient  is equal accross all Dentist categories and method used for treatment for Alloy 2

# %% [markdown]
# # Alternate Hopthesis:Avg implant hardness of the patient  is  not equal accross all Dentist categories and method used for treatment for Alloy 2

# %%
formula = 'Response ~ C(Dentist) + C(Method)'
model = ols(formula, Alloy2_data).fit()
aov_table = anova_lm(model)
(aov_table)
# Out:
#               df         sum_sq        mean_sq          F    PR(>F)
# C(Dentist)   4.0   56797.911111   14199.477778   0.926215  0.458933
# C(Method)    2.0  499640.400000  249820.200000  16.295479  0.000008
# Residual    38.0  582564.488889   15330.644444        NaN       NaN

# %% [markdown]
# # The p-value of both the treatments is less than  𝛼(0.05) hence the alternate hypothesis is true so the Avg implant hardness of the patient  is  not equal accross all Dentist categories and method used for treatment for Alloy 2

# %% [markdown]
# #Statistically, At 5% level of significance,The implant hardness not dependant on dentist but it gets affected by method that used for impanting for Alloy 2

# %%
#lets check interaction effect between method & Dentist used for implanting for Alloy 2
sns.pointplot(x='Dentist', y='Response', data=Alloy2_data, hue='Method',ci=None);
# Out:
# C:\Users\mantr\AppData\Local\Temp\ipykernel_10060\2714591126.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(x='Dentist', y='Response', data=Alloy2_data, hue='Method',ci=None);

# %% [markdown]
# # There is some interaction betweent method of treatment and Dentist for Alloy 2

# %% [markdown]
# # The Hypothesis for the Two Way ANOVA with Interaction effect for Alloy 1are:

# %% [markdown]
# # Null Hypothesis: There is no Interaction between Dentist and Method  used for implanting for Alloy 1

# %% [markdown]
# # Alternate Hopthesis: There is Interaction between Dentist and Method  used for implanting for Alloy1

# %%
formula = 'Response ~ C(Dentist) + C(Method) + C(Dentist):C(Method)'
model = ols(formula, Alloy1_data).fit()
aov_table = anova_lm(model)
(aov_table)
# Out:
#                         df         sum_sq       mean_sq          F    PR(>F)
# C(Dentist)             4.0  106683.688889  26670.922222   3.899638  0.011484
# C(Method)              2.0  148472.177778  74236.088889  10.854287  0.000284
# C(Dentist):C(Method)   8.0  185941.377778  23242.672222   3.398383  0.006793
# Residual              30.0  205180.000000   6839.333333        NaN       NaN

# %% [markdown]
# Due to the inclusion of the interaction effect term, we can see a change in the p-value of the first two treatments as compared to the Two-Way ANOVA without the interaction effect terms.And we see that the p-value of the interaction effect term of 'Dentist' and 'Method suggests that the Null Hypothesis is rejected in this case.
#
# The Dentist and method  taken together have direct impact on the days of hospitialization for Alloy 1

# %% [markdown]
# # The Hypothesis for the Two Way ANOVA with Interaction effect for Alloy 2 are:
# Null Hypothesis: There is no Interaction between Dentist and Method  used for implanting for Alloy 2
# Alternate Hopthesis: There is Interaction between Dentist and Method  used for implanting for Alloy 2

# %%
formula = 'Response ~ C(Dentist) + C(Method) + C(Dentist):C(Method)'
model = ols(formula, Alloy2_data).fit()
aov_table = anova_lm(model)
(aov_table)
# Out:
#                         df         sum_sq        mean_sq          F    PR(>F)
# C(Dentist)             4.0   56797.911111   14199.477778   1.106152  0.371833
# C(Method)              2.0  499640.400000  249820.200000  19.461218  0.000004
# C(Dentist):C(Method)   8.0  197459.822222   24682.477778   1.922787  0.093234
# Residual              30.0  385104.666667   12836.822222        NaN       NaN

# %% [markdown]
# Due to the inclusion of the interaction effect term, we can see a change in the p-value of the first two treatments as compared to the Two-Way ANOVA without the interaction effect terms.And we see that the p-value of the interaction effect term of 'Dentist' and 'Method suggests that the we fail to reject Null Hypothesis in this case.
#
# The Dentist and Method taken together dont have direct impact on the Implanting hardness for Alloy 2
#
# Dentist independently taken have no effect of the days on the Implanting hardness for Alloy 2
#
# We are 99% confident that Method used for implanting are calibrating the relationship between Dentist and implant hardness(Response)

# %% [markdown]
# # 7.7 Now consider the effect of both factors, dentist, and method, separately on each alloy. What do you conclude? Is it possible to identify which dentists are different, which methods are different, and which interaction levels are different?

# %%
#lets check interaction effect of Dentist used for implanting for Alloy 1

# %%
if 'Dentist:Method' in aov_table.index:
    # Perform Tukey's HSD test on interaction levels
    interaction_levels = Alloy1_data['Dentist'] + ':' + Alloy1_data['Method']
    mc = MultiComparison(Alloy1_data['Response'], interaction_levels)
    tukey_results = mc.allpairtest(sm.stats.multicomp.pairwise_tukeyhsd, method='bonferroni')
    
    # Print Tukey's HSD test results
    print(tukey_results[0])
else:
    print("No significant interaction effect.")
# Out:
# No significant interaction effect.

# %%
tukey_results.plot_simultaneous(figsize=(7,4))
plt.vlines(x=741.77,ymin=-0.5,ymax=3.5, color="red") ;

# %%
if 'Dentist:Method' in aov_table.index:
    # Perform Tukey's HSD test on interaction levels
    interaction_levels = Alloy2_data['Dentist'] + ':' + Alloy2_data['Method']
    mc = MultiComparison(Alloy2_data['Response'], interaction_levels)
    tukey_results = mc.allpairtest(sm.stats.multicomp.pairwise_tukeyhsd, method='bonferroni')
    
    # Print Tukey's HSD test results
    print(tukey_results[0])
else:
    print("No significant interaction effect.")
# Out:
# No significant interaction effect.

# %%
tukey_results.plot_simultaneous(figsize=(7,4))
plt.vlines(x=741.77,ymin=-0.5,ymax=3.5, color="red") ;
